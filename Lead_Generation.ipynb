# %% [markdown]
# # Lead Generation 📈
# ---
# **Assignment** - **Soubhagya Swain** ✍️
# **Company** - **My Equation**
#
# ## About Me 👨‍💻
# Hello! I'm **Soubhagya Swain**, a recent graduate with a Bachelor's in Business Administration from **Trident Academy of Creative Technology**. I have strong skills in **data analysis**, **business analysis**, and **project management**. I am passionate about leveraging data to drive insights and solve business problems. My goal is to apply my knowledge in real-world scenarios and contribute meaningfully to an organization's success.
#
# With experience in tools like **Excel**, **Power BI**, **Tableau**, and **SQL**, I am keen on using these skills to provide actionable insights for business growth. I am constantly learning and excited to explore new opportunities that challenge my analytical and problem-solving abilities. 🚀
#
# ## Project Overview 📊
# This assignment explores **lead demographics** and **sourcing efficiency**. The project aims to simulate a dataset of leads, incorporating demographic details and sourcing information. The task involves analyzing the data using **statistical methods** and **visualizations** to uncover actionable insights and provide data-driven recommendations for optimizing lead generation strategies. 📈
#
# ---
# **Let's Connect** 🤝
# Feel free to reach out for collaborations or project opportunities!

# %% [markdown]
# **Dataset Generation**

# %%
import pandas as pd
import random
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

locations_colleges = {
    "Mumbai": [
        "Indian Institute of Technology Bombay", "Tata Institute of Social Sciences",
        "University of Mumbai", "Narsee Monjee Institute of Management Studies", "St. Xavier's College"
    ],
    "Delhi": [
        "Jawaharlal Nehru University", "University of Delhi",
        "Indian Institute of Technology Delhi", "Jamia Millia Islamia", "All India Institute of Medical Sciences"
    ],
    "Bangalore": [
        "Indian Institute of Science", "Indian Institute of Management Bangalore",
        "Bangalore University", "RV College of Engineering", "Christ University"
    ],
    "Chennai": [
        "Indian Institute of Technology Madras", "University of Madras",
        "Anna University", "Loyola College", "Madras Christian College"
    ],
    "Hyderabad": [
        "Indian Institute of Technology Hyderabad", "University of Hyderabad",
        "Osmania University", "Birla Institute of Technology and Science, Hyderabad",
        "Jawaharlal Nehru Technological University, Hyderabad"
    ],
    "Kolkata": [
        "Indian Institute of Technology Kharagpur", "University of Calcutta",
        "Jadavpur University", "Presidency University", "Indian Statistical Institute"
    ],
    "Jaipur": [
        "Malaviya National Institute of Technology Jaipur", "University of Rajasthan",
        "Birla Institute of Technology and Science, Pilani", "Manipal University Jaipur",
        "St. Xavier's College, Jaipur"
    ],
    "Agra": [
        "Dr. Bhimrao Ambedkar University", "St. John's College", "Agra College",
        "Dayalbagh Educational Institute", "Hindustan College of Science and Technology"
    ],
    "Varanasi": [
        "Banaras Hindu University", "Mahatma Gandhi Kashi Vidyapith",
        "Sampurnanand Sanskrit University", "Central Hindu School", "Ashoka Institute of Technology and Management"
    ],
    "Amritsar": [
        "Guru Nanak Dev University", "Khalsa College, Amritsar",
        "Sri Guru Ram Das University of Health Sciences", "BBK DAV College for Women",
        "Hindu College, Amritsar"
    ],
    "Udaipur": [
        "Mohanlal Sukhadia University", "Maharana Pratap University of Agriculture and Technology",
        "Pacific University", "Janardan Rai Nagar Rajasthan Vidyapeeth University", "Vidya Bhawan Polytechnic College"
    ],
    "Goa": [
        "Goa University", "Birla Institute of Technology and Science, Goa",
        "National Institute of Oceanography", "Goa College of Engineering",
        "Padre Conceicao College of Engineering"
    ],
    "Shimla": [
        "Himachal Pradesh University", "Indian Institute of Advanced Study",
        "Indira Gandhi Medical College", "St. Bede's College", "DAV Centenary Public School, Shimla"
    ],
    "Rishikesh": [
        "All India Institute of Medical Sciences, Rishikesh", "Uttarakhand Sanskrit University",
        "Parmarth Niketan", "Dev Sanskriti Vishwavidyalaya", "Sri Hemkunt Sahib Public School"
    ],
    "Ahmedabad": [
        "Indian Institute of Management Ahmedabad", "Indian Institute of Technology Gandhinagar",
        "Gujarat University", "Nirma University", "CEPT University"
    ],
    "Pune": [
        "Indian Institute of Technology Pune", "University of Pune",
        "Fergusson College", "College of Engineering, Pune", "Symbiosis International University"
    ],
    "Lucknow": [
        "University of Lucknow", "Indian Institute of Management Lucknow",
        "Babasaheb Bhimrao Ambedkar University", "Amity University, Lucknow",
        "King George's Medical University"
    ],
    "Srinagar": [
        "University of Kashmir", "National Institute of Technology Srinagar",
        "Sher-e-Kashmir University of Agricultural Sciences and Technology of Kashmir",
        "Government Medical College, Srinagar", "Amar Singh College"
    ],
    "Mysore": [
        "University of Mysore", "National Institute of Engineering, Mysore",
        "All India Institute of Speech and Hearing", "JSS Academy of Higher Education & Research",
        "Mahajana Education Society"
    ]
}

years_of_study = ["1st", "2nd", "3rd", "4th"]
program_interests = [
    "Data Science", "Robotics", "AI", "Electric Vehicle", "Finance",
    "Data Analytics", "Business Analytics", "Software Engineering",
    "Prompt Engineering", "Accounting"
]
lead_sources = ["Instagram", "LinkedIn", "College", "Collaboration", "Google Form", "Mass-Mailing", "WhatsApp"]

num_rows = 50000
dataset = []

for i in range(1, num_rows + 1):
    location = random.choice(list(locations_colleges.keys()))
    dataset.append({
        "Lead_ID": f"LD{i}",
        "Location": location,
        "College": random.choice(locations_colleges[location]),
        "Year_of_Study": random.choice(years_of_study),
        "Program_Interest": random.choice(program_interests),
        "Lead_Source": random.choice(lead_sources)
    })

lead = pd.DataFrame(dataset)

output_path = r"C:\Users\soubh\VsCode\Lead_Generation.csv"

lead.to_csv(output_path, index=False)

# %% [markdown]
# ## Dataset Overview
#
# The dataset contains the following attributes:
#
# - **Lead_ID**: A unique identifier for each student.
# - **Location**: The geographical location of the student.
# - **College Name**: The name of the college the student is attending.
# - **Program Interest**: The program the student is interested in.
# - **Year of Study**: The current year of study of the student (e.g., 1st year, 2nd year, etc.).
# - **College Type**: Indicates whether the college is located in a **rural** or **urban** area.
#
# Each record corresponds to a unique student, providing valuable insights into lead demographics and sourcing efficiency.

# %%
lead.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Lead_ID           50000 non-null  object
#  1   Location          50000 non-null  object
#  2   College           50000 non-null  object
#  3   Year_of_Study     50000 non-null  object
#  4   Program_Interest  50000 non-null  object
#  5   Lead_Source       50000 non-null  object
# dtypes: object(6)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Dataset Overview 📊
#
# The **Dataset** is cleaned and contains no null values, ensuring that all the analysis can be done without manipulating the data too much. It has been prepared to maintain its integrity and to allow for smooth analysis with minimal preprocessing required. This ensures accurate and reliable results from the applied statistical methods and visualizations. 🔍
#
# ---

# %%
lead.describe()
# Out:
#         Lead_ID Location                                College Year_of_Study  \
# count     50000    50000                                  50000         50000
# unique    50000       19                                     95             4
# top     LD50000   Jaipur  Indian Institute of Technology Madras           4th
# freq          1     2781                                    601         12638
#
#        Program_Interest Lead_Source
# count             50000       50000
# unique               10           7
# top             Finance   Instagram
# freq               5135        7246

# %%
lead.head(10)
# Out:
#   Lead_ID   Location                                   College Year_of_Study  \
# 0     LD1  Ahmedabad  Indian Institute of Management Ahmedabad           2nd
# 1     LD2    Kolkata              Indian Statistical Institute           1st
# 2     LD3     Shimla       DAV Centenary Public School, Shimla           4th
# 3     LD4       Pune                        University of Pune           1st
# 4     LD5      Delhi   All India Institute of Medical Sciences           4th
# 5     LD6   Srinagar                     University of Kashmir           2nd
# 6     LD7  Rishikesh             Dev Sanskriti Vishwavidyalaya           2nd
# 7     LD8    Chennai     Indian Institute of Technology Madras           2nd
# 8     LD9   Varanasi          Sampurnanand Sanskrit University           3rd
# 9    LD10  Hyderabad                   University of Hyderabad           1st
#
#      Program_Interest   Lead_Source
# 0    Electric Vehicle     Instagram
# 1             Finance   Google Form
# ...

# %%
lead.tail(5)
# Out:
#        Lead_ID Location                             College Year_of_Study  \
# 49995  LD49996   Shimla  Indian Institute of Advanced Study           3rd
# 49996  LD49997    Delhi         Jawaharlal Nehru University           3rd
# 49997  LD49998  Kolkata              University of Calcutta           3rd
# 49998  LD49999  Lucknow           Amity University, Lucknow           3rd
# 49999  LD50000   Shimla  Indian Institute of Advanced Study           4th
#
#       Program_Interest    Lead_Source
# 49995         Robotics       WhatsApp
# 49996   Data Analytics      Instagram
# 49997       Accounting        College
# 49998         Robotics  Collaboration
# 49999          Finance  Collaboration

# %% [markdown]
# **Demographic Analysis**

# %% [markdown]
# ## Objective
#
# - **Analyze the data** to identify trends in lead sourcing based on:
#   - Location
#   - College
#   - Year of Study
#
# - **Highlight any significant patterns or anomalies** that could provide actionable insights for improving lead sourcing and targeting strategies.

# %%
lead.groupby("Location").size()
# Out:
# Location
# Agra         2572
# Ahmedabad    2535
# Amritsar     2597
# Bangalore    2600
# Chennai      2685
# Delhi        2692
# Goa          2646
# Hyderabad    2640
# Jaipur       2781
# Kolkata      2647
# Lucknow      2591
# Mumbai       2588
# Mysore       2606
# Pune         2625
# Rishikesh    2583
# Shimla       2662
# Srinagar     2603
# Udaipur      2579
# Varanasi     2768
# dtype: int64

# %%
lead.groupby("Location").size().plot(kind="bar", color="pink")
plt.xlabel("Location")
plt.ylabel("Number of Leads")
plt.title("Leads by Location")
plt.gcf().set_size_inches(10, 5)
for bar in plt.gca().containers[0]:
  plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(int(bar.get_height())), ha='center', va='bottom')
plt.show()

# %% [markdown]
# <small>Most Leads Came From Udaipur</small>

# %%
Most_Leads = lead.groupby(["Location", "Lead_Source"])['Lead_ID'].count()
pd.set_option('display.max_rows', 500)
Most_Leads
# Out:
# Location   Lead_Source
# Agra       Collaboration    402
#            College          341
#            Google Form      345
#            Instagram        380
#            LinkedIn         379
#            Mass-Mailing     346
#            WhatsApp         379
# Ahmedabad  Collaboration    349
#            College          382
#            Google Form      317
#            Instagram        403
#            LinkedIn         377
#            Mass-Mailing     349
#            WhatsApp         358
# Amritsar   Collaboration    345
#            College          385
#            Google Form      355
#            Instagram        376
#            LinkedIn         353
#            Mass-Mailing     385
#            WhatsApp         398
# Bangalore  Collaboration    370
#            College          371
#            Google Form      401
#            Instagram        388
#            LinkedIn         377
#            Mass-Mailing     384
#            WhatsApp         309
# ...

# %% [markdown]
# <small> A Detailed list of leads from each source from their respective location </small>

# %%
Most_Leads_Jaipur = lead[lead['Location'] == "Jaipur"].groupby(["Location","Lead_Source"])['Lead_ID'].count()
Most_Leads_Jaipur
# Out:
# Location  Lead_Source
# Jaipur    Collaboration    397
#           College          399
#           Google Form      396
#           Instagram        430
#           LinkedIn         377
#           Mass-Mailing     425
#           WhatsApp         357
# Name: Lead_ID, dtype: int64

# %%
Most_Leads_Jaipur.plot(kind="bar", color="pink")
plt.xlabel("Lead Source")
plt.ylabel("Number of Leads")
plt.gcf().set_size_inches(10, 5)
plt.title("Leads by Source in Udaipur")
for bar in plt.gca().containers[0]:
  plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(int(bar.get_height())), ha='center', va='bottom')
plt.show()

# %% [markdown]
# <small> Most of the leads in Jaipur came from Instagram.</small>

# %%
lead.head(1)
# Out:
#   Lead_ID   Location                                   College Year_of_Study  \
# 0     LD1  Ahmedabad  Indian Institute of Management Ahmedabad           2nd
#
#    Program_Interest Lead_Source
# 0  Electric Vehicle   Instagram

# %%
By_Year_Lead_Source = lead.groupby(['Year_of_Study', 'Lead_Source']).size().unstack()
By_Year_Lead_Source.plot(kind='bar', stacked=True)
plt.title("Lead Sources by Year of Study")
plt.xlabel("Year of Study")
plt.ylabel("Number of Leads")
plt.gcf().set_size_inches(15, 7)
plt.legend(title='Lead Sources', loc='upper right')
plt.show()

# %% [markdown]
# <small>Lead Analysis from different years of study</small>

# %%
lead.groupby("College").size().sort_values(ascending=False)
# Out:
# College
# Indian Institute of Technology Madras                                           601
# University of Rajasthan                                                         590
# Manipal University Jaipur                                                       577
# Birla Institute of Technology and Science, Goa                                  576
# Banaras Hindu University                                                        571
# Central Hindu School                                                            567
# Indian Institute of Technology Delhi                                            565
# Birla Institute of Technology and Science, Pilani                               559
# Jawaharlal Nehru Technological University, Hyderabad                            558
# Vidya Bhawan Polytechnic College                                                558
# St. Bede's College                                                              558
# ...

# %% [markdown]
# <small>IIT Madras Got The Most Leads</small>

# %%
lead[lead['College'] == 'Indian Institute of Technology Madras' ].groupby(["College","Lead_Source"]).size()
# Out:
# College                                Lead_Source
# Indian Institute of Technology Madras  Collaboration     88
#                                        College           78
#                                        Google Form       93
#                                        Instagram         82
#                                        LinkedIn          68
#                                        Mass-Mailing      86
#                                        WhatsApp         106
# dtype: int64

# %% [markdown]
# <small>Indian Institute of Technology Madras Generated Leads From Whatsapp</small>

# %% [markdown]
# <small>Top 10 College With The Most Leads</small>

# %%
lead.groupby("College").size().sort_values(ascending=False).head(10)
# Out:
# College
# Indian Institute of Technology Madras                   601
# University of Rajasthan                                 590
# Manipal University Jaipur                               577
# Birla Institute of Technology and Science, Goa          576
# Banaras Hindu University                                571
# Central Hindu School                                    567
# Indian Institute of Technology Delhi                    565
# Birla Institute of Technology and Science, Pilani       559
# Jawaharlal Nehru Technological University, Hyderabad    558
# Vidya Bhawan Polytechnic College                        558
# dtype: int64

# %%
lead.groupby("College").size().sort_values(ascending=False).head(10).plot(kind="bar", color="pink")
plt.xlabel("College")
plt.ylabel("Number of Leads")
plt.title("Leads by College")
plt.gcf().set_size_inches(10, 5)
for bar in plt.gca().containers[0]:
  plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(int(bar.get_height())), ha='center', va='bottom')

# %% [markdown]
# <small> Top 10 College By Leads</small>

# %%
College_Leads = lead
College_Leads.drop(columns=['Year_of_Study','Lead_ID'])
# Out:
#         Location                                   College  \
# 0      Ahmedabad  Indian Institute of Management Ahmedabad
# 1        Kolkata              Indian Statistical Institute
# 2         Shimla       DAV Centenary Public School, Shimla
# 3           Pune                        University of Pune
# 4          Delhi   All India Institute of Medical Sciences
# ...          ...                                       ...
# 49995     Shimla        Indian Institute of Advanced Study
# 49996      Delhi               Jawaharlal Nehru University
# 49997    Kolkata                    University of Calcutta
# 49998    Lucknow                 Amity University, Lucknow
# 49999     Shimla        Indian Institute of Advanced Study
#
#          Program_Interest    Lead_Source
# 0        Electric Vehicle      Instagram
# 1                 Finance    Google Form
# 2          Data Analytics   Mass-Mailing
# 3              Accounting    Google Form
# 4      Prompt Engineering       LinkedIn
# ...

# %%
College_Leads.groupby(['Lead_Source','Program_Interest'])['Lead_ID'].count()
# Out:
# Lead_Source    Program_Interest
# Collaboration  AI                      718
#                Accounting              729
#                Business Analytics      672
#                Data Analytics          679
#                Data Science            738
#                Electric Vehicle        698
#                Finance                 745
#                Prompt Engineering      728
#                Robotics                671
#                Software Engineering    735
# College        AI                      720
#                Accounting              730
#                Business Analytics      726
#                Data Analytics          701
#                Data Science            694
#                Electric Vehicle        716
#                Finance                 744
#                Prompt Engineering      686
#                Robotics                719
#                Software Engineering    725
# Google Form    AI                      694
# ...

# %% [markdown]
# **Program Analysis**

# %% [markdown]
# Objective:
# - Compare the interest levels for various e-learning programs and provide recommendations on which demographics should be targeted more aggressively.

# %%
lead.groupby('Program_Interest')['Lead_ID'].count()
# Out:
# Program_Interest
# AI                      4957
# Accounting              5078
# Business Analytics      4915
# Data Analytics          4886
# Data Science            4971
# Electric Vehicle        5047
# Finance                 5135
# Prompt Engineering      5016
# Robotics                4939
# Software Engineering    5056
# Name: Lead_ID, dtype: int64

# %% [markdown]
# <small> Student Showed Most Interest In Finance </small>

# %%
lead.groupby('Program_Interest')['Lead_ID'].count().plot(color='lightgreen')
plt.gcf().set_size_inches(10, 5)
plt.title("Program Interest")
plt.ylabel("Number of Leads")
# Out:
# Text(0, 0.5, 'Number of Leads')

# %%
lead.groupby(['Year_of_Study','Program_Interest'])['Lead_ID'].count()
# Out:
# Year_of_Study  Program_Interest
# 1st            AI                      1200
#                Accounting              1293
#                Business Analytics      1277
#                Data Analytics          1177
#                Data Science            1259
#                Electric Vehicle        1246
#                Finance                 1331
#                Prompt Engineering      1204
#                Robotics                1240
#                Software Engineering    1255
# 2nd            AI                      1246
#                Accounting              1239
#                Business Analytics      1198
#                Data Analytics          1251
#                Data Science            1299
#                Electric Vehicle        1273
#                Finance                 1242
#                Prompt Engineering      1237
#                Robotics                1210
#                Software Engineering    1271
# 3rd            AI                      1262
# ...

# %% [markdown]
# <small>Program Interest with the lowest leads from 1st year to 4th year students</small>

# %%
lead.groupby(['Year_of_Study','Program_Interest'])['Lead_ID'].count().nsmallest(10).plot(kind='bar', color='lightgreen')
plt.gcf().set_size_inches(13, 5)
plt.xlabel("Year of Study, Program Interest")
plt.ylabel("Number of Leads")
plt.title("Least Leads by Year of Study and Program Interest")
# Out:
# Text(0.5, 1.0, 'Least Leads by Year of Study and Program Interest')

# %%
lead.groupby(['Year_of_Study','Program_Interest'])['Lead_ID'].count().nsmallest(10).sort_values(ascending=False).plot(kind='line', color='lightgreen')
plt.gcf().set_size_inches(13, 5)
plt.xlabel("Year of Study, Program Interest")
plt.ylabel("Number of Leads")
plt.title("Least Leads by Year of Study and Program Interest")
# Out:
# Text(0.5, 1.0, 'Least Leads by Year of Study and Program Interest')

# %% [markdown]
# Urban and Rural Side Comparison

# %%
colleges = {
    "Mumbai": ["Indian Institute of Technology Bombay", "Tata Institute of Social Sciences",
               "University of Mumbai", "Narsee Monjee Institute of Management Studies", "St. Xavier's College"],
    "Delhi": ["Jawaharlal Nehru University", "University of Delhi",
              "Indian Institute of Technology Delhi", "Jamia Millia Islamia", "All India Institute of Medical Sciences"],
    "Bangalore": ["Indian Institute of Science", "Indian Institute of Management Bangalore",
                  "Bangalore University", "RV College of Engineering", "Christ University"],
    "Chennai": ["Indian Institute of Technology Madras", "University of Madras",
                "Anna University", "Loyola College", "Madras Christian College"],
    "Hyderabad": ["Indian Institute of Technology Hyderabad", "University of Hyderabad",
                  "Osmania University", "Birla Institute of Technology and Science, Hyderabad",
                  "Jawaharlal Nehru Technological University, Hyderabad"],
    "Kolkata": ["Indian Institute of Technology Kharagpur", "University of Calcutta",
                "Jadavpur University", "Presidency University", "Indian Statistical Institute"],
    "Jaipur": ["Malaviya National Institute of Technology Jaipur", "University of Rajasthan",
               "Birla Institute of Technology and Science, Pilani", "Manipal University Jaipur",
               "St. Xavier's College, Jaipur"],
    "Agra": ["Dr. Bhimrao Ambedkar University", "St. John's College", "Agra College",
             "Dayalbagh Educational Institute", "Hindustan College of Science and Technology"],
    "Varanasi": ["Banaras Hindu University", "Mahatma Gandhi Kashi Vidyapith",
                 "Sampurnanand Sanskrit University", "Central Hindu School", "Ashoka Institute of Technology and Management"],
    "Amritsar": ["Guru Nanak Dev University", "Khalsa College, Amritsar",
                 "Sri Guru Ram Das University of Health Sciences", "BBK DAV College for Women",
                 "Hindu College, Amritsar"],
    "Udaipur": ["Mohanlal Sukhadia University", "Maharana Pratap University of Agriculture and Technology",
                "Pacific University", "Janardan Rai Nagar Rajasthan Vidyapeeth University", "Vidya Bhawan Polytechnic College"],
    "Goa": ["Goa University", "Birla Institute of Technology and Science, Goa",
            "National Institute of Oceanography", "Goa College of Engineering",
            "Padre Conceicao College of Engineering"],
    "Shimla": ["Himachal Pradesh University", "Indian Institute of Advanced Study",
               "Indira Gandhi Medical College", "St. Bede's College", "DAV Centenary Public School, Shimla"],
    "Rishikesh": ["All India Institute of Medical Sciences, Rishikesh", "Uttarakhand Sanskrit University",
                  "Parmarth Niketan", "Dev Sanskriti Vishwavidyalaya", "Sri Hemkunt Sahib Public School"],
    "Ahmedabad": ["Indian Institute of Management Ahmedabad", "Indian Institute of Technology Gandhinagar",
                  "Gujarat University", "Nirma University", "CEPT University"],
    "Pune": ["Indian Institute of Technology Pune", "University of Pune",
             "Fergusson College", "College of Engineering, Pune", "Symbiosis International University"],
    "Lucknow": ["University of Lucknow", "Indian Institute of Management Lucknow",
                "Babasaheb Bhimrao Ambedkar University", "Amity University, Lucknow",
                "King George's Medical University"],
    "Srinagar": ["University of Kashmir", "National Institute of Technology Srinagar",
                 "Sher-e-Kashmir University of Agricultural Sciences and Technology of Kashmir",
                 "Government Medical College, Srinagar", "Amar Singh College"],
    "Mysore": ["University of Mysore", "National Institute of Engineering, Mysore",
               "All India Institute of Speech and Hearing", "JSS Academy of Higher Education & Research",
               "Mahajana Education Society"]
}

urban_cities = ["Mumbai", "Delhi", "Bangalore", "Chennai", "Hyderabad", "Kolkata", "Pune", "Lucknow", "Ahmedabad", "Goa"]
rural_cities = [city for city in colleges.keys() if city not in urban_cities]

data = {"City": [], "College": [], "Category": []}
for city, college_list in colleges.items():
    for college in college_list:
        data["City"].append(city)
        data["College"].append(college)
        data["Category"].append("Urban" if city in urban_cities else "Rural")

RU = pd.DataFrame(data)
urban_colleges = RU[RU["Category"] == "Urban"]
rural_colleges = RU[RU["Category"] == "Rural"]

# %% [markdown]
# <small>Urban Colleges Are Larger in number in comparison to Rural In The Dataset</small>

# %%
RU.groupby("Category").size()
# Out:
# Category
# Rural    45
# Urban    50
# dtype: int64

# %%
sns.countplot(data=RU, x="Category", palette="pink")
plt.ylabel("Number of Colleges")
plt.title("Number of Urban and Rural Colleges")
# Out:
# C:\Users\soubh\AppData\Local\Temp\ipykernel_12032\826791650.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=RU, x="Category", palette="pink")
# Text(0.5, 1.0, 'Number of Urban and Rural Colleges')

# %%
lead_temp = pd.read_csv('Lead_Generation.csv')

# %%
lead_temp = lead_temp.merge(RU, on="College")

# %%
lead_temp.groupby("Category").size()
# Out:
# Category
# Rural    23751
# Urban    26249
# dtype: int64

# %% [markdown]
# <small>Urban Colleges are higher in Leads compared to rural colleges</small>

# %%
lead_temp.groupby("Category")['Lead_ID'].count().plot(kind="bar", color="lightgreen")
# Out:
# <Axes: xlabel='Category'>

# %%
lead_temp.groupby(["Category","Program_Interest"])['Lead_ID'].count()
# Out:
# Category  Program_Interest
# Rural     AI                      2394
#           Accounting              2399
#           Business Analytics      2301
#           Data Analytics          2306
#           Data Science            2376
#           Electric Vehicle        2401
#           Finance                 2461
#           Prompt Engineering      2381
#           Robotics                2388
#           Software Engineering    2344
# Urban     AI                      2563
#           Accounting              2679
#           Business Analytics      2614
#           Data Analytics          2580
#           Data Science            2595
#           Electric Vehicle        2646
#           Finance                 2674
#           Prompt Engineering      2635
#           Robotics                2551
#           Software Engineering    2712
# Name: Lead_ID, dtype: int64

# %% [markdown]
# <small>Urban Colleges Student are showing more interest in the program compared to the rural colleges in every offered program</small>

# %%
lead_temp.groupby(["Category","Program_Interest"])['Lead_ID'].count().plot(kind="bar", color="lightgreen")
plt.gcf().set_size_inches(15, 7)

# %%
lead_temp.groupby(["Category","Lead_Source"])['Lead_ID'].count()
# Out:
# Category  Lead_Source
# Rural     Collaboration    3406
#           College          3378
#           Google Form      3395
#           Instagram        3396
#           LinkedIn         3332
#           Mass-Mailing     3410
#           WhatsApp         3434
# Urban     Collaboration    3707
#           College          3783
#           Google Form      3801
#           Instagram        3850
#           LinkedIn         3698
#           Mass-Mailing     3771
#           WhatsApp         3639
# Name: Lead_ID, dtype: int64

# %% [markdown]
# <small> Leads Distribution by Rural And Urban Colleges</small>

# %%
sns.countplot(data=lead_temp, x="Category", hue="Lead_Source", palette="pink")
plt.gcf().set_size_inches(17, 10)
plt.ylabel("Number of Leads")
plt.title("Leads by Source in Urban and Rural Colleges")
# Out:
# Text(0.5, 1.0, 'Leads by Source in Urban and Rural Colleges')

# %%
lead_temp[lead_temp['Category'] == "Urban"].groupby(["Category",'Year_of_Study',"Lead_Source"])['Lead_ID'].count()
# Out:
# Category  Year_of_Study  Lead_Source
# Urban     1st            Collaboration     907
#                          College           966
#                          Google Form       955
#                          Instagram         968
#                          LinkedIn          917
#                          Mass-Mailing      954
#                          WhatsApp          917
#           2nd            Collaboration     961
#                          College           913
#                          Google Form       962
#                          Instagram         949
#                          LinkedIn          894
#                          Mass-Mailing      959
#                          WhatsApp          898
#           3rd            Collaboration     927
#                          College           938
#                          Google Form       936
#                          Instagram         929
#                          LinkedIn          928
# ...

# %% [markdown]
# <small> Urban College Students Leads Distribution by Current Year of study</small>

# %%
sns.countplot(data=lead_temp[lead_temp['Category'] == "Urban"], x="Year_of_Study", hue="Lead_Source", palette="pink")
plt.gcf().set_size_inches(15, 7)
plt.ylabel("Number of Leads")
plt.title("Leads by Source in Urban Colleges by Year of Study")
# Out:
# Text(0.5, 1.0, 'Leads by Source in Urban Colleges by Year of Study')

# %%
lead_temp[lead_temp['Category'] == "Rural"].groupby(["Category",'Year_of_Study',"Lead_Source"])['Lead_ID'].count()
# Out:
# Category  Year_of_Study  Lead_Source
# Rural     1st            Collaboration    843
#                          College          831
#                          Google Form      807
#                          Instagram        807
#                          LinkedIn         812
#                          Mass-Mailing     859
#                          WhatsApp         939
#           2nd            Collaboration    862
#                          College          867
#                          Google Form      832
#                          Instagram        890
#                          LinkedIn         797
#                          Mass-Mailing     841
#                          WhatsApp         841
#           3rd            Collaboration    881
#                          College          836
#                          Google Form      897
#                          Instagram        841
#                          LinkedIn         857
#                          Mass-Mailing     840
# ...

# %% [markdown]
# <small> Urban College Students Leads Distribution by Current Year of study</small>

# %%
sns.countplot(data=lead_temp[lead_temp['Category'] == "Rural"], x="Year_of_Study", hue="Lead_Source", palette="pink")
plt.gcf().set_size_inches(15, 7)
plt.ylabel("Number of Leads")
plt.title("Leads by Source in Rural Colleges by Year of Study")
# Out:
# Text(0.5, 1.0, 'Leads by Source in Rural Colleges by Year of Study')

# %%
lead_temp = lead_temp.drop(columns=["City"])

# %%
sns.countplot(data=lead_temp, x="Category", hue="Program_Interest", palette="rainbow")
plt.ylabel("Number of Leads")
plt.gcf().set_size_inches(17, 10)
plt.legend(title='Program Interest', loc='upper right')
plt.title("Leads by Program Interest in Urban and Rural Colleges")
# Out:
# Text(0.5, 1.0, 'Leads by Program Interest in Urban and Rural Colleges')

# %%
lead_counts = lead_temp.groupby(["Year_of_Study", "Category"]).size().reset_index(name="Lead_Count")
sns.lineplot(data=lead_counts, x="Year_of_Study", y="Lead_Count", hue="Category", palette="pastel", marker='o') 
plt.ylabel("Number of Leads")
plt.title("Number of Leads by Year of Study and Category")
plt.gcf().set_size_inches(15, 7)
plt.show()

# %%
lead_temp.head(10)
# Out:
#   Lead_ID   Location                                   College Year_of_Study  \
# 0     LD1  Ahmedabad  Indian Institute of Management Ahmedabad           2nd
# 1     LD2    Kolkata              Indian Statistical Institute           1st
# 2     LD3     Shimla       DAV Centenary Public School, Shimla           4th
# 3     LD4       Pune                        University of Pune           1st
# 4     LD5      Delhi   All India Institute of Medical Sciences           4th
# 5     LD6   Srinagar                     University of Kashmir           2nd
# 6     LD7  Rishikesh             Dev Sanskriti Vishwavidyalaya           2nd
# 7     LD8    Chennai     Indian Institute of Technology Madras           2nd
# 8     LD9   Varanasi          Sampurnanand Sanskrit University           3rd
# 9    LD10  Hyderabad                   University of Hyderabad           1st
#
#      Program_Interest   Lead_Source Category
# 0    Electric Vehicle     Instagram    Urban
# ...

# %% [markdown]
# **Projection & Predictions**

# %% [markdown]
# ### 💰 Budget Allocation for Leads:
#
# To allocate the marketing budget, a fixed value of **2 units** per lead was assigned. This decision ensures that every lead, irrespective of its source, location, or program interest, receives an equal share of the budget. The total budget for the marketing campaign was then calculated by multiplying the number of leads by the allocated value of 2.
#
# This approach simplifies the budget allocation process, enabling efficient resource distribution while allowing for further analysis of lead sources and program interests without complicating the financial aspect of the project. 🎯
#
# By using a consistent budget per lead, the project can focus on evaluating the performance of different lead sources and program interests without the need for complex financial calculations. 🔍

# %%
lead_temp
# Out:
#        Lead_ID   Location                                   College  \
# 0          LD1  Ahmedabad  Indian Institute of Management Ahmedabad
# 1          LD2    Kolkata              Indian Statistical Institute
# 2          LD3     Shimla       DAV Centenary Public School, Shimla
# 3          LD4       Pune                        University of Pune
# 4          LD5      Delhi   All India Institute of Medical Sciences
# ...        ...        ...                                       ...
# 49995  LD49996     Shimla        Indian Institute of Advanced Study
# 49996  LD49997      Delhi               Jawaharlal Nehru University
# 49997  LD49998    Kolkata                    University of Calcutta
# 49998  LD49999    Lucknow                 Amity University, Lucknow
# 49999  LD50000     Shimla        Indian Institute of Advanced Study
#
#       Year_of_Study    Program_Interest    Lead_Source Category
# 0               2nd    Electric Vehicle      Instagram    Urban
# ...

# %%
sns.lineplot(data=lead_source_counts, x="Lead_Source", y="Budget_Allocation", marker='o', color='blue')
plt.ylabel("Budget Allocation")
plt.title("Budget Allocation by Lead Source")
plt.gcf().set_size_inches(15, 7)

# %%
sns.lmplot(data=lead_source_counts, x="Lead_Count", y="Budget_Allocation", hue="Lead_Source", palette="bright")
plt.ylabel("Budget Allocation")
plt.xlabel("Number of Leads")
plt.title("Budget Allocation vs. Number of Leads by Lead Source")
plt.gcf().set_size_inches(15, 7)
